# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.isnull().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                     False
# reading score                  False
# writing score                  False
# dtype: bool

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.countplot(data['gender'], palette='winter')
# Out:
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\3872496374.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['gender'], palette='winter')
# <Axes: xlabel='count', ylabel='gender'>

# %%
sns.countplot(data['race/ethnicity'], palette='winter')
# Out:
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\2692702945.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['race/ethnicity'], palette='winter')
# <Axes: xlabel='count', ylabel='race/ethnicity'>

# %%
sns.countplot(data['lunch'], palette='winter')
# Out:
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\2268989536.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['lunch'], palette='winter')
# <Axes: xlabel='count', ylabel='lunch'>

# %%
sns.countplot(data['parental level of education'], palette='winter')
plt.xticks(rotation=45)
# Out:
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\1404132986.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['parental level of education'], palette='winter')
# (array([  0.,  50., 100., 150., 200., 250.]),
#  [Text(0.0, 0, '0'),
#   Text(50.0, 0, '50'),
#   Text(100.0, 0, '100'),
#   Text(150.0, 0, '150'),
#   Text(200.0, 0, '200'),
#   Text(250.0, 0, '250')])

# %%
data.groupby('race/ethnicity').size().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %%
data.groupby('parental level of education').size().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.countplot(data=data, x='gender', hue='race/ethnicity', palette='winter')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=data, x='lunch', hue='gender', palette='winter')
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
sns.distplot(data['math score'])
print("Skewness :", data['math score'].skew())
# Out:
# Skewness : -0.27893514909431694
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\1592273389.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['math score'])

# %%
sns.distplot(data['reading score'])
print("Skewness :", data['reading score'].skew())
# Out:
# Skewness : -0.25910451810923063
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\1490824714.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['reading score'])

# %%
sns.distplot(data['writing score'])
print("Skewness :", data['writing score'].skew())
# Out:
# Skewness : -0.28944397150761897
# C:\Users\GSR1\AppData\Local\Temp\ipykernel_34824\1068657130.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['writing score'])

# %%
sns.boxplot(x=data['gender'],y=data['math score'])
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
data2 = data[["math score", "reading score", "writing score"]]
sns.heatmap(data2.corr())
# Out:
# <Axes: >
